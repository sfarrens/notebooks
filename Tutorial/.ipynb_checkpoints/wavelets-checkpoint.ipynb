# %% [markdown]
# # <font color='blue'>Introduction to Wavelets</font>
#
# ---
#
# <img src="images/cea_logo.png" width="100" align="right">
#
#
# > Author: **Samuel Farrens**
#
# > Year: **2016**
#
# > Version: **1.0**
#
# > Email: **[samuel.farrens@cea.fr](mailto:samuel.farrens@cea.fr)**
#
# > Web: **[CosmoStat Website](http://www.cosmostat.org/)**
#
#
# ## <font color='blue'>Contents</font>
#
# ---
#
# 1. [Set-Up](#Set-Up)
# 1. [Introduction](#Introduction)

# %% [markdown]
# ## <font color='blue'>Set-Up</font>
#
# ---
#
# Here we will import a couple of packages that we will need throughout the notebook.

# %%
# Tell Jupyter to display plots in this notebook.
# %matplotlib inline

# Import the numpy package with the alias np.
import numpy as np           

# Import the pyplot package from matplotlib with the alias plt.
import matplotlib.pyplot as plt  
from matplotlib import pylab
pylab.rcParams['figure.figsize'] = (10.0, 8.0)

# Import some tools from scipy.
from scipy import fftpack, signal

# SOME USEFUL FUNCTIONS

# Function to calculate an orthonormal descrete cosine transform.
def fft(signal):

    return fftpack.fft(signal)

# Function to calculate an orthonormal descrete cosine transform.
def ifft(signal):

    return fftpack.ifft(signal)

def hide_axes(axis):
    
    axis.xaxis.set_ticklabels([])
    axis.yaxis.set_ticklabels([])

# %% [markdown]
# ## <font color='blue'>Introduction</font>
#
# ---

# %%
t = np.linspace(-1, 1, 200, endpoint=False)
sig  = np.cos(2 * np.pi * 7 * t) + signal.gausspulse(t - 0.4, fc=2)
sig /= max(sig)

sig_fft = np.abs(fftpack.fftshift(fft(sig)))

ax1 = plt.subplot(211)
ax1.plot(t, sig, 'b-')
ax1.plot([-0.5, -0.5], [-1, 1], 'r--')
ax1.plot([0.0, 0.0], [-1, 1], 'r--')
ax1.plot([0.5, 0.5], [-1, 1], 'r--')
plt.text(-0.76, 0.8, 'A', color='red')
plt.text(-0.26, 0.8, 'B', color='red')
plt.text(0.24, 0.8, 'C', color='red')
plt.text(0.74, 0.8, 'D', color='red')
ax1.set_xlabel('Time [s]')
hide_axes(ax1)
ax2 = plt.subplot(212)
ax2.plot(t, sig_fft, 'b-')
ax2.set_xlabel('Frequency [Hz]')
hide_axes(ax2)
plt.show()

# %%
a = slice(0,50)
b = slice(50, 100)
c = slice(100, 150)
d = slice(150, 200)

sig_fft_a = np.abs(fftpack.fftshift(fft(sig[a])))
sig_fft_b = np.abs(fftpack.fftshift(fft(sig[b])))
sig_fft_c = np.abs(fftpack.fftshift(fft(sig[c])))
sig_fft_d = np.abs(fftpack.fftshift(fft(sig[d])))

ax1 = plt.subplot(241)
ax1.plot(t[a], sig[a], 'b-')
ax1.set_xlabel('Time [s]')
ax1.set_title('A')
hide_axes(ax1)
ax2 = plt.subplot(242)
ax2.plot(t[b], sig[b], 'b-')
ax2.set_xlabel('Time [s]')
ax2.set_title('B')
hide_axes(ax2)
ax3 = plt.subplot(243)
ax3.plot(t[c], sig[c], 'b-')
ax3.set_xlabel('Time [s]')
ax3.set_title('C')
hide_axes(ax3)
ax4 = plt.subplot(244)
ax4.plot(t[d], sig[d], 'b-')
ax4.set_xlabel('Time [s]')
ax4.set_title('D')
hide_axes(ax4)
ax5 = plt.subplot(245)
ax5.plot(t[a], sig_fft_a, 'b-')
ax5.set_xlabel('Frequency [Hz]')
hide_axes(ax5)
ax6 = plt.subplot(246)
ax6.plot(t[b], sig_fft_b, 'b-')
ax6.set_xlabel('Frequency [Hz]')
hide_axes(ax6)
ax7 = plt.subplot(247)
ax7.plot(t[c], sig_fft_c, 'b-')
ax7.set_xlabel('Frequency [Hz]')
hide_axes(ax7)
ax8 = plt.subplot(248)
ax8.plot(t[d], sig_fft_d, 'b-')
ax8.set_xlabel('Frequency [Hz]')
hide_axes(ax8)
plt.tight_layout()
plt.show()
